# %% [markdown]
# # Correct the mistakes identified by pylint.
# Based on the report given by pylint changes were made to this code to address the following issues.
# Exactly one space required after comma
# Exactly one space required around assignment

# %%
def add(num1, num2):
    
    return num1 + num2

num1 = 4
num2 = 5

total = add(num1, num2)

print("The sum of {} and {} is {}".format(num1, num2, total))

# %%
# Now go and run on the terminal this path and see the score of this code:
# C:\Users\Lenovo\Final Project\Python Coding Practices and Packaging Concepts\Static_Code_Analysis_Good_Score.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Your task
# Improve the score in this code to a perfect 10 by correcting all the issues pointed out by pylint. If cant figure out how to solve some issues it is helpful to google the pylint message.
