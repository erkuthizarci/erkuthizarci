# %% [markdown]
# # Hands-on Lab: Static Code Analysis

# %% [markdown]
# # Objectives
# After completing this lab you will be able to:
#
# Install pylint package
# Run Static Code Analysis on a python program
# Check the compliance score of a python program.
# Fix common mistakes and improve the compliance score.

# %% [markdown]
# # Install the pylint package

# %%
# !pip install pylint
# Out:
# Requirement already satisfied: pylint in c:\users\lenovo\anaconda3\lib\site-packages (2.14.5)
# Requirement already satisfied: typing-extensions>=3.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (4.3.0)
# Requirement already satisfied: isort<6,>=4.2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (5.9.3)
# Requirement already satisfied: mccabe<0.8,>=0.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (0.6.1)
# Requirement already satisfied: platformdirs>=2.2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (2.5.2)
# Requirement already satisfied: dill>=0.2 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (0.3.4)
# Requirement already satisfied: colorama>=0.4.5 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (0.4.5)
# Requirement already satisfied: tomli>=1.1.0 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (2.0.1)
# Requirement already satisfied: astroid<=2.12.0-dev0,>=2.11.6 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (2.11.7)
# Requirement already satisfied: tomlkit>=0.10.1 in c:\users\lenovo\anaconda3\lib\site-packages (from pylint) (0.11.1)
# Requirement already satisfied: lazy-object-proxy>=1.4.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint) (1.6.0)
# Requirement already satisfied: setuptools>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint) (63.4.1)
# Requirement already satisfied: wrapt<2,>=1.11 in c:\users\lenovo\anaconda3\lib\site-packages (from astroid<=2.12.0-dev0,>=2.11.6->pylint) (1.14.1)

# %% [markdown]
# # Create a sample python file for static code analysis

# %%
# Define a function named 'add' that takes two arguments, 'number1' and 'number2'

def add(number1, number2):
    
    # The function returns the sum of 'number1' and 'number2'.
    
    return number1 + number2

# Initialize the variable 'num1' with the value 4.

num1 = 4

# Initialize the variable 'num2' with the value 5.

num2 = 5

# Call the 'add' function with 'num1' and 'num2' as arguments and store the result in 'total'.

total = add(num1, num2)

# Print the result of adding 'num1' and 'num2' using the 'format' method to insert the values into the string.

print("The sum of {} and {} is {}".format(num1, num2, total))
# Out:
# The sum of 4 and 5 is 9

# %%
# Now go and run on the terminal this path and see the score of this code:
# C:\Users\Lenovo\Final Project\Python Coding Practices and Packaging Concepts\Static_Code_Analysis_Bad_Score.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)
